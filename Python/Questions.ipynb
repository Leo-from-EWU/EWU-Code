# %% [markdown]
# # Python Practice Questions
# Welcome to your dedicated questions notebook! You can add and practice all your important Python questions here.

# %% [markdown]
# ---
# ## Question 1: Menu-Based Dictionary Operations
#
# **Problem Statement:**
# Create a dictionary where:
# - Keys = student names
# - Values = marks (integer)
#
# Write a menu-based program where the user presses a key ('A', 'B', 'C', 'D') depending on the operation they want to perform on the dictionary:
# 1. Add a student (`A`)
# 2. Update marks (`B`)
# 3. Search for a student (`C`)
# 4. Display all students and marks (`D`)

# %%
# Solution for Question 1
students = {}

while True:
    print("\n--- Menu ---")
    print("A. Add a student")
    print("B. Update marks")
    print("C. Search for a student")
    print("D. Display all students")
    print("Q. Quit")

    k = input("Enter A, B, C, D or Q to quit: ").upper()

    match k:
        case "A":
            name = input("Enter student name: ")
            marks = int(input("Enter marks: "))
            students[name] = marks
            print("Student added successfully!")

        case "B":
            name = input("Enter student name: ")
            if name in students:
                marks = int(input("Enter new marks: "))
                students[name] = marks
                print("Marks updated successfully!")
            else:
                print("Student not found.")

        case "C":
            name = input("Enter student name: ")
            if name in students:
                print("Marks:", students[name])
            else:
                print("Student not found.")

        case "D":
            print("\nStudent Information:")
            if not students: # Quick check if dictionary is empty
                print("No students added yet!")
            else:
                for name, marks in students.items():
                    print("Name:", name, "| Marks:", marks)
        
        case "Q":
            print("Goodbye!")
            break  # This breaks us out of the while loop to stop the program

        case _:
            print("Invalid option. Try again.")

# %% [markdown]
# ---
# ## Question 2: Merge and Sort Lists
#
# **Problem Statement:**
# Input two lists of integers from the user. Merge them into one list and sort the result.
#
# Eg - `list1 = [1, 2, 7]`, `list2 = [3, 4, 5]`
#
# `result = [1, 2, 3, 4, 5, 7]`

# %%
list1=[1,2,7]
list2=[3,4,5]
list3=[]
list3= list1+list2
list3.sort()
for i in range(6):
    print("Result: \n",list3[i])

# %% [markdown]
# ---
# ## Question 3: Words Length Dictionary
#
# **Problem Statement:**
# Given a list of words:
# `words = ["apple", "banana", "kiwi", "cherry", "mango"]`
#
# Create a dictionary that maps each word to its length.
#
# Example:
# `{"apple": 5, "banana": 6, "kiwi": 4, ...}`

# %%
words = ["apple", "banana", "kiwi", "cherry", "mango"]

for word in words:
    for letter in word:
        print(letter)
    print("Length:", len(word))

# %% [markdown]
# ---
# ## Question 4: No Common Elements
#
# **Problem Statement:**
# Write a program to check whether two lists share no common elements.
#
# ```python
# # share no common elements
# list1 = [1, 2, 3, 4]
# list2 = [5, 6, 7, 8]
#
# # share common elements
# list1 = [1, 2, 3]
# list2 = [3, 4]
# ```
#
# [Hint - use sets]

# %%
list1=[1,2,3]
list2=[3,4]
list3=[]
list3=list1+list2
number= set(list3)

for i in number:
    print(i)

# %% [markdown]
# ---
# ## Question 5: Duplicate Elements
#
# **Problem Statement:**
# Given a list, print all elements that appear more than once in the list.
#
# [Hint - use sets]

# %%
numbers = [1, 2, 3, 2, 4, 5, 3, 6, 1]

seen = set()
duplicates = set()

for num in numbers:
    if num in seen: #we are seeing is the num exist in seen
        duplicates.add(num)
    else:
        seen.add(num)

print("Duplicate elements:", duplicates)

# %% [markdown]
# ---
# ## Question 6: Unique Characters
#
# **Problem Statement:**
# Ask the user for a string and print:
# - All unique characters
# - The count of unique characters

# %%
s = input("Enter the string\n")

for i in set(s):
    count = 0

    for j in s:
        if j == i:
            count = count + 1

    if count == 1:
        print(i)
